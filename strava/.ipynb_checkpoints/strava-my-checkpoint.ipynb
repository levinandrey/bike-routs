# %%
from __future__ import print_function
import time
import swagger_client
from swagger_client.rest import ApiException
from pprint import pprint

# Configure OAuth2 access token for authorization: strava_oauth
configuration = swagger_client.Configuration()
configuration.access_token = 'dd81f0fa9886082552133a969fa80bb3a90c5300'

# create an instance of the API class
api_instance = swagger_client.RoutesApi(swagger_client.ApiClient(configuration))
id = 22636627 # int | The identifier of the athlete.
page = 1 # int | Page number. (optional)
per_page = 5 # int | Number of items per page. Defaults to 30. (optional)

try:
    # List Athlete Routes
    api_response = api_instance.get_routes_by_athlete_id(id, page=page, per_page=per_page)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling RoutesApi->get_routes_by_athlete_id: %s\n" % e)
# Out:
# [{'athlete': {'city': '',
#              'country': '',
#              'created_at': datetime.datetime(2017, 6, 12, 14, 42, 16, tzinfo=tzutc()),
#              'firstname': 'Andrey',
#              'follower': None,
#              'friend': None,
#              'id': 22636627,
#              'lastname': 'Levin',
#              'premium': False,
#              'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/large.jpg',
#              'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/medium.jpg',
#              'resource_state': 2,
#              'sex': 'M',
#              'state': '',
#              'summit': False,
#              'updated_at': datetime.datetime(2019, 8, 12, 4, 0, 38, tzinfo=tzutc())},
#  'description': '',
#  'directions': None,
#  'distance': 98339.73534538597,
#  'elevation_gain': 299.8880217156867,
#  'id': 21658272,
#  'map': {'id': 'r21658272',
#          'polyline': None,
#          'summary_polyline': 'ou_zI{`ccFyCty@_w@sNq_@gQoAbAsV~xAsf@dpBmLxYo@bLlBbG{iFtyM}rEhrL{AlGwKtsAeClJtaAvuCtJ`n@dPpd@rg@pzDpXjx@jFxc@~Ttw@|XzkAxf@brA`eBjzCtZng@hRnVnCtP`MntB|UheAQjl@eRrfAeZ`dAjDf_C_@dl@oFnNqVz[e[vdAaL|N}BbHs`@bfBkBtSKzVlDl]nTjx@p^v_AjbAjzBnLng@vDn`@hDfmDW|rBjWxvCxErT|EnLv_AnlAvElL`DlSxKviCzBxTjv@rvCfD}FgD|Fl@liAiBj}O{If|ArNrw@EdWaCpE`EoElGxOrAnIpJg@pIlPnf@np@neAcq@rb@`ErWvNlf@jFx|@noBxwA`t@p{@gRfGfBjaBpwAfZlm@db@xc@pZ}sAzNwrAFko@qLg]uHg|At@qb@nnAyjFrV{p@rTcsA`Rk|@p`@}`ApXck@`W_SvkAqSrXoOqDgo@cGg_@aJsXo@cLqZi~@sPw^gEww@nAuq@pGwZ|{AwaElEuiAwD_cAmJ_`@eFc_@ep@_QaMmPePc_@w\\mh@cCeA'},
#  'name': 'ups Кимры - Конаково',
#  'private': False,
#  'segments': None,
#  'starred': False,
#  'sub_type': 1,
#  'timestamp': 1568149687,
#  'type': 1},
#  {'athlete': {'city': '',
#              'country': '',
#              'created_at': datetime.datetime(2017, 6, 12, 14, 42, 16, tzinfo=tzutc()),
#              'firstname': 'Andrey',
#              'follower': None,
#              'friend': None,
#              'id': 22636627,
#              'lastname': 'Levin',
#              'premium': False,
#              'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/large.jpg',
#              'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/medium.jpg',
#              'resource_state': 2,
#              'sex': 'M',
#              'state': '',
#              'summit': False,
#              'updated_at': datetime.datetime(2019, 8, 12, 4, 0, 38, tzinfo=tzutc())},
#  'description': '',
#  'directions': None,
#  'distance': 51534.35235692531,
#  'elevation_gain': 157.89000000000007,
#  'id': 16625854,
#  'map': {'id': 'r16625854',
#          'polyline': None,
#          'summary_polyline': 'o{xuIu}{qEnMc]}FeIkCmKoEyGrBmXiAqUlBoHp@wOe@aXgGp@i@gRcW~Bk@uUkGNAuPkIuHaBoj@eGz@U{F_XqXqfBmfAw[eH}eAyo@ui@q}@{]yaA{z@aiA_qAsZucAtSiK?gm@kPqiAkg@s~@isAmLeH_j@eOiQ_R{HySmP}}@yXki@uIoe@wJgN}MF_m@pr@kdAvKsHtDepA|}BaHfG_yCzYi`C_~OmHu[wGkPafCm}DwIiToT{~@mbB_oCqwA_kCebD{lG_^a}@yU_t@wJwRyPiRmZ_Rki@nJ'},
#  'name': 'Зубцов - Старица',
#  'private': False,
#  'segments': None,
#  'starred': True,
#  'sub_type': 1,
#  'timestamp': 1567470985,
#  'type': 1},
#  {'athlete': {'city': '',
#              'country': '',
#              'created_at': datetime.datetime(2017, 6, 12, 14, 42, 16, tzinfo=tzutc()),
#              'firstname': 'Andrey',
#              'follower': None,
#              'friend': None,
#              'id': 22636627,
#              'lastname': 'Levin',
#              'premium': False,
#              'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/large.jpg',
#              'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/medium.jpg',
#              'resource_state': 2,
#              'sex': 'M',
#              'state': '',
#              'summit': False,
#              'updated_at': datetime.datetime(2019, 8, 12, 4, 0, 38, tzinfo=tzutc())},
#  'description': '',
#  'directions': None,
#  'distance': 104341.69066894818,
#  'elevation_gain': 473.6576523459621,
#  'id': 17337486,
#  'map': {'id': 'r17337486',
#          'polyline': None,
#          'summary_polyline': 'uw{wIujetE|QsEJrInBfCvGiATzKlVrAydBvoHmf@`jAqGnfA}@zf@gJxtAi[eGyNq`@{Xyd@iPq`@qSqMgWat@kf@_{@sQcRof@iUwY~Ly}@x@{n@_MQlHPmHxBNs@_CeA}tAiCc\\yHad@_@gNbEerBgSinDiNeZaFur@kJu]qIcNcRaMoSmYeOkm@Pap@tCwa@aHoy@S{NhCi^^qm@xH{Vs@_WbHeoAgCcvA}Nk~@{c@exBeSmv@e^qcAuHk_@kJ_r@t@_{A}@mXed@}mAeSqo@BkJfD_Z@i_@bZm`AfVui@nJivAiHk_@yJmjBaN}g@{ByGkZu\\mVeh@gYeBgUa_@iSco@y\\ao@st@gg@}IeQid@ye@q^aCwUi\\yf@`EqOsK_j@oJcHsEgGsNmLsu@oVu^ax@cuBelAsuAgO_]oEmRkz@anG`OyxJgmAqc@yPXkL|Ee[~e@__@h_@ubAbj@eR|Tyv@rC{Pq`C_Icq@tA{r@q@eiAoCia@iGub@oS{t@udAcpBk[ewAkMmR{u@gyBgWmiAeFw]wFssAaJs[e@qYqKid@eDwBcr@aByh@oVc_AmCwq@hMsq@oAaIdGmOx[mGl@iAwd@bDsINkFOjFjAb@nBaGxFidBKcZoBkNXar@vBuN`e@su@w@{o@gDac@JwY{Cc^KeYjFuFrI|JrD|MzANpDeFdFgVrT_[fW_q@xR{]vTyq@r@yQd]y_Aa@}`@aLif@}Dyi@e@}d@iDsUyB_kBoLowC\\oEy@cBvp@wImDkmAgMaiAyPa}BhLyFlh@ib@uCyT|@uRx\\qfC'},
#  'name': 'Старица - Тверь',
#  'private': False,
#  'segments': None,
#  'starred': True,
#  'sub_type': 1,
#  'timestamp': 1567470965,
#  'type': 1},
#  {'athlete': {'city': '',
#              'country': '',
#              'created_at': datetime.datetime(2017, 6, 12, 14, 42, 16, tzinfo=tzutc()),
#              'firstname': 'Andrey',
#              'follower': None,
#              'friend': None,
#              'id': 22636627,
#              'lastname': 'Levin',
#              'premium': False,
#              'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/large.jpg',
#              'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/medium.jpg',
#              'resource_state': 2,
#              'sex': 'M',
#              'state': '',
#              'summit': False,
#              'updated_at': datetime.datetime(2019, 8, 12, 4, 0, 38, tzinfo=tzutc())},
#  'description': '',
#  'directions': None,
#  'distance': 60659.4601011949,
#  'elevation_gain': 244.42283704190191,
#  'id': 18585257,
#  'map': {'id': 'r18585257',
#          'polyline': None,
#          'summary_polyline': 'q~wuIy||qEpCkKDiG_ZuRcHyVQgMlBoHp@wOsAcwAfBgKZ}pAzCyQtDih@@y`@cBqIu_@sZgL{XqQkBsVwo@yOyWcLoB}WgOqWkc@uP{a@wMwOc`@mcAqLgQ_SywCyEsc@sEm|@oPcdAG}UiBsXw[ehD{]wrAmB{DqPiLcEoPgCiu@dWizArAeVGkO{Jy`AeIyOge@i`@cqAoYkQ{YkQsLcOwOkGsUCsQ_IcOcFbA_XnV_X|JeIqDiMw\\wx@oSaAuOmWg^iKkYcOl\\c^uBiTaG_LnIgI}Uv@oFkDuKiFaI{JgChB}J`CqD{K{BeIca@\\yBuAaHeTe]_D}Ks@}]bBeSuEeKm@qLiB{A_B_rAmEalA{Jcs@wSq`@iDiC{HpE{JqNa{@}Ic\\hHkTyEs^f@mOwFqi@xJeDjDgLje@wQjh@uTbP_Zp]wYhs@w^|PacBf^iVwM_z@ybAghAm\\}i@a_@ozAeyBylAeuAiqAuf@wX|Cmv@zd@{\\~Gsu@oYoQ}AgRdBcj@tXcEIwx@rdB~Fvu@'},
#  'name': 'Зубцов -  Старица',
#  'private': False,
#  'segments': None,
#  'starred': True,
#  'sub_type': 1,
#  'timestamp': 1567470961,
#  'type': 1},
#  {'athlete': {'city': '',
#              'country': '',
#              'created_at': datetime.datetime(2017, 6, 12, 14, 42, 16, tzinfo=tzutc()),
#              'firstname': 'Andrey',
#              'follower': None,
#              'friend': None,
#              'id': 22636627,
#              'lastname': 'Levin',
#              'premium': False,
#              'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/large.jpg',
#              'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/medium.jpg',
#              'resource_state': 2,
#              'sex': 'M',
#              'state': '',
#              'summit': False,
#              'updated_at': datetime.datetime(2019, 8, 12, 4, 0, 38, tzinfo=tzutc())},
#  'description': '',
#  'directions': None,
#  'distance': 76019.60156648091,
#  'elevation_gain': 494.32938353326097,
#  'id': 15163010,
#  'map': {'id': 'r15163010',
#          'polyline': None,
#          'summary_polyline': 'cggoI{ao~EjAcBh[lOq@dKoAlAeG}JoEnR`IvuBe@xKd@yK_HotBhE}RhFbJnAmAp@eKmPwGwGgGfOeoA~XgvAcm@cuBni@qd@|hB_lCpCcHxLsq@xw@}f@ts@gs@~e@{r@p[qz@|Rmw@rGo@xFkIjFIlh@k}@tLkBdQ~XvT|KbiAbTxTh@~j@qu@jb@up@`[i\\x`BawAvKi]vDcUvVvAzKua@b^cq@tM}\\jS{TnAkf@|Isa@vDc^pNgx@fWknAjH_Wj@oY`YqcAbQce@ha@q_BrLiW|RyLnQiVdT{`@dLmd@zTscEhHel@FggAcC_lAvEkq@Kgu@jPgwAjBa^?kXyB_h@qGwj@H{WtGa^lWkp@~c@olBfV_{CdC_OdOge@vMis@dCg[bBur@EkCcEo@i@~CWxEzEnCTxBUyB{EoCVyEh@_DbEn@G}a@hJ{\\vSqvB}H_k@iIq}@gi@wt@kCmMli@_wJpByMjTs_@xBaOmJkl@qk@giB_H_k@e\\gmBcNkhBs@keAwQocBkGq[wVsq@wDcx@aP_`Asp@oqCui@{mAp`@{j@sSuo@gMs~@s\\_oAoUsZua@k@'},
#  'name': 'Обнинск - Серпухов',
#  'private': False,
#  'segments': None,
#  'starred': True,
#  'sub_type': 1,
#  'timestamp': 1565824098,
#  'type': 1}]

# %%
for item in api_response:
    print("\n\n\nITEM")
    
    pprint(item)
# Out:
# ITEM
# {'athlete': {'city': '',
#              'country': '',
#              'created_at': datetime.datetime(2017, 6, 12, 14, 42, 16, tzinfo=tzutc()),
#              'firstname': 'Andrey',
#              'follower': None,
#              'friend': None,
#              'id': 22636627,
#              'lastname': 'Levin',
#              'premium': False,
#              'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/large.jpg',
#              'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/medium.jpg',
#              'resource_state': 2,
#              'sex': 'M',
#              'state': '',
#              'summit': False,
#              'updated_at': datetime.datetime(2019, 8, 12, 4, 0, 38, tzinfo=tzutc())},
#  'description': '',
#  'directions': None,
#  'distance': 98339.73534538597,
#  'elevation_gain': 299.8880217156867,
#  'id': 21658272,
#  'map': {'id': 'r21658272',
#          'polyline': None,
#          'summary_polyline': 'ou_zI{`ccFyCty@_w@sNq_@gQoAbAsV~xAsf@dpBmLxYo@bLlBbG{iFtyM}rEhrL{AlGwKtsAeClJtaAvuCtJ`n@dPpd@rg@pzDpXjx@jFxc@~Ttw@|XzkAxf@brA`eBjzCtZng@hRnVnCtP`MntB|UheAQjl@eRrfAeZ`dAjDf_C_@dl@oFnNqVz[e[vdAaL|N}BbHs`@bfBkBtSKzVlDl]nTjx@p^v_AjbAjzBnLng@vDn`@hDfmDW|rBjWxvCxErT|EnLv_AnlAvElL`DlSxKviCzBxTjv@rvCfD}FgD|Fl@liAiBj}O{If|ArNrw@EdWaCpE`EoElGxOrAnIpJg@pIlPnf@np@neAcq@rb@`ErWvNlf@jFx|@noBxwA`t@p{@gRfGfBjaBpwAfZlm@db@xc@pZ}sAzNwrAFko@qLg]uHg|At@qb@nnAyjFrV{p@rTcsA`Rk|@p`@}`ApXck@`W_SvkAqSrXoOqDgo@cGg_@aJsXo@cLqZi~@sPw^gEww@nAuq@pGwZ|{AwaElEuiAwD_cAmJ_`@eFc_@ep@_QaMmPePc_@w\\mh@cCeA'},
#  'name': 'ups Кимры - Конаково',
#  'private': False,
#  'segments': None,
#  'starred': False,
#  'sub_type': 1,
#  'timestamp': 1568149687,
#  'type': 1}
#
#
#
# ITEM
# {'athlete': {'city': '',
#              'country': '',
#              'created_at': datetime.datetime(2017, 6, 12, 14, 42, 16, tzinfo=tzutc()),
#              'firstname': 'Andrey',
#              'follower': None,
#              'friend': None,
#              'id': 22636627,
#              'lastname': 'Levin',
#              'premium': False,
#              'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/large.jpg',
#              'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/medium.jpg',
#              'resource_state': 2,
#              'sex': 'M',
#              'state': '',
#              'summit': False,
#              'updated_at': datetime.datetime(2019, 8, 12, 4, 0, 38, tzinfo=tzutc())},
#  'description': '',
#  'directions': None,
#  'distance': 51534.35235692531,
#  'elevation_gain': 157.89000000000007,
#  'id': 16625854,
#  'map': {'id': 'r16625854',
#          'polyline': None,
#          'summary_polyline': 'o{xuIu}{qEnMc]}FeIkCmKoEyGrBmXiAqUlBoHp@wOe@aXgGp@i@gRcW~Bk@uUkGNAuPkIuHaBoj@eGz@U{F_XqXqfBmfAw[eH}eAyo@ui@q}@{]yaA{z@aiA_qAsZucAtSiK?gm@kPqiAkg@s~@isAmLeH_j@eOiQ_R{HySmP}}@yXki@uIoe@wJgN}MF_m@pr@kdAvKsHtDepA|}BaHfG_yCzYi`C_~OmHu[wGkPafCm}DwIiToT{~@mbB_oCqwA_kCebD{lG_^a}@yU_t@wJwRyPiRmZ_Rki@nJ'},
#  'name': 'Зубцов - Старица',
#  'private': False,
#  'segments': None,
#  'starred': True,
#  'sub_type': 1,
#  'timestamp': 1567470985,
#  'type': 1}
#
#
#
# ITEM
# {'athlete': {'city': '',
#              'country': '',
#              'created_at': datetime.datetime(2017, 6, 12, 14, 42, 16, tzinfo=tzutc()),
#              'firstname': 'Andrey',
#              'follower': None,
#              'friend': None,
#              'id': 22636627,
#              'lastname': 'Levin',
#              'premium': False,
#              'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/large.jpg',
#              'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/medium.jpg',
#              'resource_state': 2,
#              'sex': 'M',
#              'state': '',
#              'summit': False,
#              'updated_at': datetime.datetime(2019, 8, 12, 4, 0, 38, tzinfo=tzutc())},
#  'description': '',
#  'directions': None,
#  'distance': 104341.69066894818,
#  'elevation_gain': 473.6576523459621,
#  'id': 17337486,
#  'map': {'id': 'r17337486',
#          'polyline': None,
#          'summary_polyline': 'uw{wIujetE|QsEJrInBfCvGiATzKlVrAydBvoHmf@`jAqGnfA}@zf@gJxtAi[eGyNq`@{Xyd@iPq`@qSqMgWat@kf@_{@sQcRof@iUwY~Ly}@x@{n@_MQlHPmHxBNs@_CeA}tAiCc\\yHad@_@gNbEerBgSinDiNeZaFur@kJu]qIcNcRaMoSmYeOkm@Pap@tCwa@aHoy@S{NhCi^^qm@xH{Vs@_WbHeoAgCcvA}Nk~@{c@exBeSmv@e^qcAuHk_@kJ_r@t@_{A}@mXed@}mAeSqo@BkJfD_Z@i_@bZm`AfVui@nJivAiHk_@yJmjBaN}g@{ByGkZu\\mVeh@gYeBgUa_@iSco@y\\ao@st@gg@}IeQid@ye@q^aCwUi\\yf@`EqOsK_j@oJcHsEgGsNmLsu@oVu^ax@cuBelAsuAgO_]oEmRkz@anG`OyxJgmAqc@yPXkL|Ee[~e@__@h_@ubAbj@eR|Tyv@rC{Pq`C_Icq@tA{r@q@eiAoCia@iGub@oS{t@udAcpBk[ewAkMmR{u@gyBgWmiAeFw]wFssAaJs[e@qYqKid@eDwBcr@aByh@oVc_AmCwq@hMsq@oAaIdGmOx[mGl@iAwd@bDsINkFOjFjAb@nBaGxFidBKcZoBkNXar@vBuN`e@su@w@{o@gDac@JwY{Cc^KeYjFuFrI|JrD|MzANpDeFdFgVrT_[fW_q@xR{]vTyq@r@yQd]y_Aa@}`@aLif@}Dyi@e@}d@iDsUyB_kBoLowC\\oEy@cBvp@wImDkmAgMaiAyPa}BhLyFlh@ib@uCyT|@uRx\\qfC'},
#  'name': 'Старица - Тверь',
#  'private': False,
#  'segments': None,
#  'starred': True,
#  'sub_type': 1,
#  'timestamp': 1567470965,
#  'type': 1}
#
#
#
# ITEM
# {'athlete': {'city': '',
#              'country': '',
#              'created_at': datetime.datetime(2017, 6, 12, 14, 42, 16, tzinfo=tzutc()),
#              'firstname': 'Andrey',
#              'follower': None,
#              'friend': None,
#              'id': 22636627,
#              'lastname': 'Levin',
#              'premium': False,
#              'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/large.jpg',
#              'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/medium.jpg',
#              'resource_state': 2,
#              'sex': 'M',
#              'state': '',
#              'summit': False,
#              'updated_at': datetime.datetime(2019, 8, 12, 4, 0, 38, tzinfo=tzutc())},
#  'description': '',
#  'directions': None,
#  'distance': 60659.4601011949,
#  'elevation_gain': 244.42283704190191,
#  'id': 18585257,
#  'map': {'id': 'r18585257',
#          'polyline': None,
#          'summary_polyline': 'q~wuIy||qEpCkKDiG_ZuRcHyVQgMlBoHp@wOsAcwAfBgKZ}pAzCyQtDih@@y`@cBqIu_@sZgL{XqQkBsVwo@yOyWcLoB}WgOqWkc@uP{a@wMwOc`@mcAqLgQ_SywCyEsc@sEm|@oPcdAG}UiBsXw[ehD{]wrAmB{DqPiLcEoPgCiu@dWizArAeVGkO{Jy`AeIyOge@i`@cqAoYkQ{YkQsLcOwOkGsUCsQ_IcOcFbA_XnV_X|JeIqDiMw\\wx@oSaAuOmWg^iKkYcOl\\c^uBiTaG_LnIgI}Uv@oFkDuKiFaI{JgChB}J`CqD{K{BeIca@\\yBuAaHeTe]_D}Ks@}]bBeSuEeKm@qLiB{A_B_rAmEalA{Jcs@wSq`@iDiC{HpE{JqNa{@}Ic\\hHkTyEs^f@mOwFqi@xJeDjDgLje@wQjh@uTbP_Zp]wYhs@w^|PacBf^iVwM_z@ybAghAm\\}i@a_@ozAeyBylAeuAiqAuf@wX|Cmv@zd@{\\~Gsu@oYoQ}AgRdBcj@tXcEIwx@rdB~Fvu@'},
#  'name': 'Зубцов -  Старица',
#  'private': False,
#  'segments': None,
#  'starred': True,
#  'sub_type': 1,
#  'timestamp': 1567470961,
#  'type': 1}
#
#
#
# ITEM
# {'athlete': {'city': '',
#              'country': '',
#              'created_at': datetime.datetime(2017, 6, 12, 14, 42, 16, tzinfo=tzutc()),
#              'firstname': 'Andrey',
#              'follower': None,
#              'friend': None,
#              'id': 22636627,
#              'lastname': 'Levin',
#              'premium': False,
#              'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/large.jpg',
#              'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/22636627/9563277/1/medium.jpg',
#              'resource_state': 2,
#              'sex': 'M',
#              'state': '',
#              'summit': False,
#              'updated_at': datetime.datetime(2019, 8, 12, 4, 0, 38, tzinfo=tzutc())},
#  'description': '',
#  'directions': None,
#  'distance': 76019.60156648091,
#  'elevation_gain': 494.32938353326097,
#  'id': 15163010,
#  'map': {'id': 'r15163010',
#          'polyline': None,
#          'summary_polyline': 'cggoI{ao~EjAcBh[lOq@dKoAlAeG}JoEnR`IvuBe@xKd@yK_HotBhE}RhFbJnAmAp@eKmPwGwGgGfOeoA~XgvAcm@cuBni@qd@|hB_lCpCcHxLsq@xw@}f@ts@gs@~e@{r@p[qz@|Rmw@rGo@xFkIjFIlh@k}@tLkBdQ~XvT|KbiAbTxTh@~j@qu@jb@up@`[i\\x`BawAvKi]vDcUvVvAzKua@b^cq@tM}\\jS{TnAkf@|Isa@vDc^pNgx@fWknAjH_Wj@oY`YqcAbQce@ha@q_BrLiW|RyLnQiVdT{`@dLmd@zTscEhHel@FggAcC_lAvEkq@Kgu@jPgwAjBa^?kXyB_h@qGwj@H{WtGa^lWkp@~c@olBfV_{CdC_OdOge@vMis@dCg[bBur@EkCcEo@i@~CWxEzEnCTxBUyB{EoCVyEh@_DbEn@G}a@hJ{\\vSqvB}H_k@iIq}@gi@wt@kCmMli@_wJpByMjTs_@xBaOmJkl@qk@giB_H_k@e\\gmBcNkhBs@keAwQocBkGq[wVsq@wDcx@aP_`Asp@oqCui@{mAp`@{j@sSuo@gMs~@s\\_oAoUsZua@k@'},
#  'name': 'Обнинск - Серпухов',
#  'private': False,
#  'segments': None,
#  'starred': True,
#  'sub_type': 1,
#  'timestamp': 1565824098,
#  'type': 1}
